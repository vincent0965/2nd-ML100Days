# %%
# 練習時間
#### 請寫一個函式用來計算 Mean Square Error
$ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)
# Out:
#   File "<ipython-input-6-717ae97269d2>", line 3
#     $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 第一題
# 我選擇的競賽是Google Analytics Customer Revenue Prediction
# 1.在商業模式中，開發客戶以及鎖定客戶群是很重要的，而顧客的經濟能力是一項重要的參考指標，因此我覺得如果可以預估顧客的收入，對開發客戶可以有相當大的幫助。
# 2.數據為Google Merchandise Store的模擬數據，包含兩個時間軸:第一個為2016/8/1至2018/4/30；第二個為2018/5/1至2018/10/15號之用戶交易
# 3.文本數據
# 4.本數據希望從過往的交易數據中，預測客戶的經濟能力，我認為應該會透過交易紀錄、交易方式、交易時間判斷每一位客戶的經濟能力。
#
# 第二題
# 1.核心問題:透過預測顧客大量出入的地點與時間(上下班時間、車站等)，可以提高載客率，或者是減少出車降低成本。
# 2.資料收集:建立時間軸，以及派車地點的紀錄，也可以紀錄行駛的路線。資料收集可以透過如手機 Google Map等，記錄每一筆行車資料。
# 3.文本數據，如果是路線的話可以使用圖片或是以文字描述。
# 4.收集大量的行車資料，可以比對出叫車的熱門時間與熱門地點，模擬出一個相關的模型(如:在某個特定時間內，某個車站到某個車站之間有大量人潮)再依此去比對現實情況是否吻合。

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, y_hat):
    """
    計算MSE:
    y:實際值
    y_hat:平均值
    mse:MSE
    """
    mse=sum((y-y_hat)**2)/len(y)
    return mse
MSE=mean_squared_error(y,y_hat)
print("The Mean Squared Error is",mse)
# Out:
# The Mean Squared Error is 215.65350891116265

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)

print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 215.654
